# %%
import csv
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
data = np.load("data/fer2013.npz")
X_train = data["X_train"]
y_train = data["y_train"]

X_val = data["X_val"]
y_val = data["y_val"]

X_test = data["X_test"]
y_test = data["y_test"]

data.close()

# %%
plt.figure()

_, subplt = plt.subplots(1,3)

subplt[0].imshow(X_train[0],cmap="gray")
subplt[1].imshow(X_val[0],cmap="gray")
subplt[2].imshow(X_test[0],cmap="gray")
