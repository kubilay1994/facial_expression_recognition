# %%
import csv
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
data = np.load("data/fer2013_train.npz")
X_train = data["X_train"]
y_train = data["y_train"]

print(y_train.shape)
print(X_train.shape)
# Out:
# (28709, 7)
# (28709, 48, 48)

# %%
plt.imshow(X_train[6],cmap="gray")

# %%
val_data = np.load("data/fer2013_val.npz")
X_val = test_data["X_val"]
y_val = test_data["y_val"]

print(X_val.shape)
print(y_val.shape)
# Out:
# (3589, 48, 48)
# (3589, 7)

# %%
test_data = np.load("data/fer2013_test.npz")
X_test = test_data["X_test"]
y_test = test_data["y_test"]

print(X_test.shape)
print(y_test.shape)
# Out:
# (3589, 48, 48)
# (3589, 7)
